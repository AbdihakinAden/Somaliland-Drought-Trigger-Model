# %%
# ------------------------------------------------------------
# Notebook 05 — Merge Processed Inputs for Model Development
# ------------------------------------------------------------

import sys, os
sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.merge_inputs import merge_all

# ------------------------------------------------------------
# 1. Run merge script
# ------------------------------------------------------------

df = merge_all()

# ------------------------------------------------------------
# 2. Show preview
# ------------------------------------------------------------

print("Merged dataset preview:")
df.head()
# Out:
# ✅ merged_for_models.csv created successfully!
# 📁 Saved to: ../data/processed/merged_for_models.csv
# Merged dataset preview:
#    region      mean  year season    DHI0  DryPct  OBS
# 0   Awdal  1.247377  2020    MAM  25.052    0.00    0
# 5   Awdal -0.145574  2020    OND  52.911    0.00    1
# 10  Awdal  0.542533  2021    MAM  39.149    0.00    1
# 15  Awdal  0.027138  2021    OND  49.457    0.00    1
# 20  Awdal -1.823260  2022    MAM  86.465   84.44    1
